# %%
import pandas as Sv

# %%
b={
    "Name":["Sanjay","Lokesh","Naveen","Kabilan","Santhosh","Suriya varshini","Ashiya","Deebalaskhmi","Ashwini","Padma shree"],
    "Age":[21,20,20,20,19,20,20,20,20,20],
    "Gender":["M","M","M","M","M","F","F","F","F","F"],
    "Subject":["Maths","Maths","Maths","Maths","Maths","Maths","Maths","Maths","Maths","Maths"],
    "Marks":[90,90,95,90,94,98,90,96,93,95]
}
b=Sv.DataFrame(b)
print(b)
# Out:
#               Name  Age Gender Subject  Marks
# 0           Sanjay   21      M   Maths     90
# 1           Lokesh   20      M   Maths     90
# 2           Naveen   20      M   Maths     95
# 3          Kabilan   20      M   Maths     90
# 4         Santhosh   19      M   Maths     94
# 5  Suriya varshini   20      F   Maths     98
# 6           Ashiya   20      F   Maths     90
# 7     Deebalaskhmi   20      F   Maths     96
# 8          Ashwini   20      F   Maths     93
# 9      Padma shree   20      F   Maths     95
