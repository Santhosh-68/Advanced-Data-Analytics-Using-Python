# %%
print("hello")
# Out:
# hello

# %%
a=6
b=8
c=True
d="Good Evening"

print(d)
print(a+b)
print(a-b)
# Out:
# Good Evening
# 14
# -2

# %%
list=[2,3,4,6,7,8,9,10,11,12]
tuple=("a","b","c")
for i in range(len(list)):
    if (list[i]%5==1):
        print(list[i])
# Out:
# 6
# 11
