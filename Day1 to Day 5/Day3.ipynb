# %%
import pandas as sv

# %%
ssv=sv.read_excel('/content/studentdata.xlsx')

# %%
ssv.head()
# Out:
#      ID class  gender  race    GPA  Maths  English  Science  computer  History
# 0  1141     A    male     1  73.47    NaN       81       87        60      NaN
# 1  1142     A  female     1  71.22    NaN       50       51        51      NaN
# 2  1143     A  female     2  74.56   81.0       48       71        60     77.0
# 3  1144     A  female     1  72.89    NaN       72       38        60      NaN
# 4  1145     A  female     1  70.11   83.0       45       63        60      NaN

# %%
ssv.tail()
# Out:
#       ID class  gender  race    GPA  Maths  English  Science  computer  \
# 25  1165     A    male     3  79.56   90.0       62       76        80
# 26  1166     A  female     4  78.54   87.0       67       71        80
# 27  1167     B  female     1  77.76   89.0       46       71        80
# 28  1168     A  female     1  83.06    NaN       72       71        81
# 29  1169     A    male     1  84.04   83.0       80       85        83
#
#     History
# 25     81.0
# 26      NaN
# 27     82.0
# 28     86.0
# 29     79.0

# %%
ssv.shape
# Out:
# (30, 10)

# %%
ssv.describe()
# Out:
#                 ID       race        GPA      Maths    English    Science  \
# count    30.000000  30.000000  30.000000  16.000000  30.000000  30.000000
# mean   1154.766667   2.266667  76.755667  84.437500  62.566667  65.433333
# std       8.463648   1.892514   5.515140   3.595715  12.201423  12.864502
# min    1141.000000   1.000000  64.750000  79.000000  38.000000  38.000000
# 25%    1148.000000   1.000000  74.222500  81.750000  60.000000  56.250000
# 50%    1154.500000   1.000000  77.055000  84.500000  64.500000  65.000000
# 75%    1161.750000   3.750000  81.145000  87.250000  71.500000  71.000000
# max    1169.000000   7.000000  84.040000  90.000000  82.000000  92.000000
#
#         computer    History
# count  30.000000  18.000000
# mean   71.233333  82.166667
# std     8.443252   4.743416
# min    51.000000  76.000000
# 25%    63.000000  77.500000
# 50%    74.500000  81.500000
# 75%    78.000000  85.750000
# max    83.000000  92.000000

# %%
ssv.columns
# Out:
# Index(['ID', 'class', 'gender', 'race', 'GPA', 'Maths', 'English', 'Science',
#        'computer', 'History'],
#       dtype='object')

# %%
ssv.dtypes
# Out:
# ID            int64
# class        object
# gender       object
# race          int64
# GPA         float64
# Maths       float64
# English       int64
# Science       int64
# computer      int64
# History     float64
# dtype: object

# %%
ssv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        30 non-null     int64
#  1   class     30 non-null     object
#  2   gender    30 non-null     object
#  3   race      30 non-null     int64
#  4   GPA       30 non-null     float64
#  5   Maths     16 non-null     float64
#  6   English   30 non-null     int64
#  7   Science   30 non-null     int64
#  8   computer  30 non-null     int64
#  9   History   18 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.5+ KB
